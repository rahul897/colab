# %%
# !pip install PyDrive
# !pip install h5py

import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

download = drive.CreateFile({'id': '1oRY5rjg3zvOmLSRgkkw5ojWLKTlMTBQR'})
download.GetContentFile('700k.h5')

download = drive.CreateFile({'id': '1lpb2Ts5JVlEfBugU_5c4psJxUl7itCeu'})
download.GetContentFile('wiki.simple.vec')

download = drive.CreateFile({'id': '1-G2XRn85mYTwjUaiYGUgD9_pHZh96qCU'})
download.GetContentFile('eval1_unlabelled.tsv')

# %%
from keras import backend as K
from keras.layers import Embedding
from keras.layers import LSTM, Input, Dense ,Lambda
from keras.layers.wrappers import Bidirectional
from keras.layers.convolutional import Convolution1D
from keras.models import Model
import numpy as np
import re
from tqdm import tqdm

from keras.models import model_from_json
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
embedding_matrix = np.zeros((18216 + 1, 300))#300 if ft 50 if glove

margin = 0.05
hidden_dim = 256
enc_timesteps = 50
dec_timesteps = 50

def get_cosine_similarity():
        dot = lambda a, b: K.batch_dot(a, b, axes=1)
        return lambda x: 1-dot(x[0], x[1]) / K.maximum(K.sqrt(dot(x[0], x[0]) * dot(x[1], x[1])), K.epsilon())

qa_embedding = Embedding(18216 +  1,
                            300,
                            weights=[embedding_matrix],
                            input_length=50,
                            trainable=False)

question = Input(shape=(enc_timesteps,), dtype='int32', name='question_base')
answer = Input(shape=(dec_timesteps,), dtype='int32', name='answer')
answer_good = Input(shape=(dec_timesteps,), dtype='int32', name='answer_good_base')
answer_bad = Input(shape=(dec_timesteps,), dtype='int32', name='answer_bad_base')


bi_lstm = Bidirectional(LSTM(activation='tanh', dropout=0.2, units=hidden_dim, return_sequences=False))

# embed the question and pass it through bilstm
question_embedding =  qa_embedding(question)
question_enc_1 = bi_lstm(question_embedding)

# embed the answer and pass it through bilstm
answer_embedding =  qa_embedding(answer)
answer_enc_1 = bi_lstm(answer_embedding)

# get the cosine similarity
similarity = get_cosine_similarity()
qam = Lambda(similarity,output_shape=lambda _: (None, 1))([question_enc_1, answer_enc_1])

lstm_model = Model(name="bi_lstm", inputs=[question, answer], outputs=qam)

lstm_model.compile(loss='mean_squared_error', optimizer='rmsprop')

checkpoint = ModelCheckpoint('{epoch:02d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, mode='auto')

# %%
lstm_model.load_weights('700k.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-60353d28a66a> in <module>()
# ----> 1 lstm_model.load_weights('700k.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1164             else:
#    1165                 saving.load_weights_from_hdf5_group(
# -> 1166                     f, self.layers, reshape=reshape)
#    1167
#    1168     def _updated_config(self):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#    1056                              ' elements.')
#    1057         weight_value_tuples += zip(symbolic_weights, weight_values)
# -> 1058     K.batch_set_value(weight_value_tuples)
#    1059
#    1060
#
# ...
