# %%
'''Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''

from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = io.open(path, encoding='utf-8').read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# corpus length: 600893
# total chars: 57

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        print(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 200285/200285 [==============================] - 181s 904us/step - loss: 3.0710
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " so
# antithetical that it denies the poss"
#  so
# antithetical that it denies the poss
# enn enn enn  enn ennn ennn  enn ennn on enn enn  enn ennn   en  enn  enn enn ennn enn ennn enn enn enn en enn enn en  onnnn  ennn onn  ennn enn ennn  enn enn ennn on  ennn ennn  en  ennn   enn  ennn ennn   ennn onn ens onnn  enn enn ennnn en  enn tenn  enn enn enn    ennn onn enn t ennn en  ennn onn ennn enn enn  enn  ennn ennn  enn   enn enn  enn enn  onnnn   ennn  ennn ennn en  onnn ennnn   onnn
# ----- diversity: 0.5
# ----- Generating with seed: " so
# antithetical that it denies the poss"
#  so
# antithetical that it denies the poss
# ofn en annn en en ennn ennrh ennonnn onn, on enn enn   en onnnsansesne o errten  ennn onnn    men enssonrennno ennta   en ten enn en edessthenn e  esonnn hon  enn en  ,nnn  h ennn enn ennn ennmt  innnnlonn on e  on o o e ,t enn  ennnon onnsen ennnn ennnct t e  en   enn en ann enn n   en enn se onn hennnn,n onnn  ong   setennranlsos  an enntontenn onnntenn t  onnns  anns en  inn    onttonn   en onn
# ----- diversity: 1.0
# ----- Generating with seed: " so
# antithetical that it denies the poss"
#  so
# antithetical that it denies the poss
# on empen en,-mordinan ennsus en a
# erennse   nis,nmonrsdo colime annt,nnnsees ese,ndenntlshl  pr p,stes,n   hw iron,n olse  e y e e n  en,frwta eonmti o amem en
# unanrons tmf te eenn lthwo,nss woc ef.npegt lurons !lyncew in ennnn,n  wfon unsyte,nfs,nsen,nsode on ormannred  ons mantm inennr, wo,l,srtest,sne ho o
# ennelirtonnla
#  te  e w smhewben,o,enpes st
# ntr  gen eonw t, s  edo o  e ennssedsint.imyn
# ----- diversity: 1.2
# ----- Generating with seed: " so
# antithetical that it denies the poss"
#  so
# antithetical that it denies the poss
# hor,nsmton id,nsnjenntpdrefwo onr  enn negyf us fon ha eicon f ri i,ode  o
#   onoen u t omrt sspy ucsshwphnon edcemtad twwscrno
# esdtun e hnfs,re if b hheshfais fowhi we o,
# e
# .n,wenmhpe et
# osa  opaf
# sc  eatsnon en,nnwwtyntlec,ganostloanse o mg-towenla e  ,qonsenrtby arytsnecroscontanr ce tgh ireutwronuthes
# nannro gl
# oteg anynstsacanennonge, .me i enga  ote i  is soswolpt=segennl oncen hbint,nnmo ye
# Epoch 2/10
# 200285/200285 [==============================] - 181s 904us/step - loss: 3.0266
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "strengthen their own opinion of themselv"
# strengthen their own opinion of themselv
#  ttttttttttotttttto ttttttttotttettttttttttto tttttttttttottttottttto
# ----- diversity: 0.5
# ----- Generating with seed: "strengthen their own opinion of themselv"
# strengthen their own opinion of themselv
# ttttttttt ttotltototttondt inftlotolttot ttotettettodttt t ototonrtttttotttetttotttto tottt o ttotto tttotttttttontthedtttonttosttto t tetod  ttttocttonthonsttottttt  ttottotrtitottttot tttttttifttttttthtttettttttodttthitodtedtettt ttdtottttttonetttttottdto ottto  tttotttttttt tt tortttttttttoton yttonttotetont ittottottttttttotottedtttottttttotontttttto ltostttttottotttottttotthttotttttttttttoud
# ----- diversity: 1.0
# ----- Generating with seed: "strengthen their own opinion of themselv"
# strengthen their own opinion of themselv
# emttdltounc otrwe itys odt tco dotedtden onydntho un btoypthrtytittwubtosa itty.nlrtto tifttsu  tttudibttallttn,totaten o tf retctongolstirntnounrtoydlttdaoddttte tt oto ttttt tttwl islttcylstolstsontttidtomtda artemtatettstdo ltydatotstb i odldstlo
#  cdoctuftorsaltoutetig t owt  olt e ogdctodotsy, pigmlemmenttotf,tilotwfwoao-ootonctin mafl dtgtemeltattstogo tyrocttoct yl ttolnnteonrneosthoti urdtt
# ----- diversity: 1.2
# ----- Generating with seed: "strengthen their own opinion of themselv"
# strengthen their own opinion of themselv
# l  !tatelgtessc ododdf-osnnlted,totef s ?ltont:ota'!d-,dtulsitolrgol fto
# tey ynr-"nttmththtego coto st itetsg htoskttyltolttltttodtoncqa tmionlnceloatb;rtenltkodttto.x-sde totyd tost-tyn. nyte ithe  lftten.botsrhlh
# o.tdofd o
# tesl.boustdtt  stan
# utte odfnsttosncntso  tdidodc,dn ogwbtdbedtutnio
# toy'ltst htofrtterttuduoynetyteltell ststtighamosao tofdto nduttboutlimm ytttfi tyntote yunscbtontpollnt
# l
# Epoch 3/10
# 200285/200285 [==============================] - 181s 905us/step - loss: 3.0205
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "rd, and from his arm down into his toes "
# rd, and from his arm down into his toes
# tta ttte tat te  tt te ttett
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# ttttte ttte e te  e ttttttttta  tttttte  ta te tttttt te ta  tetttte ta te tta  e ttta te  tetttt e ttttttttte  tttt tte ttte te tttttta  a ttt e ttttttttte tttttttte tta  t e ttte  tte  ttte  e t tttte tttte ttttte ttttt e  a ttte ttttte  a  e  tte ttttt e ttte te tet te ttate  ttte  ta tte tta ttte  tattttta te ttte  e ttte tte  ta tttttttttte tta tttttta tttte tttttt
# ----- diversity: 0.5
# ----- Generating with seed: "rd, and from his arm down into his toes "
# rd, and from his arm down into his toes
# lettte  tttattaltt en ttte e tttttote t ty  e ttte  tat aeul ttirtue  el te thte al  e te e  ta runttthtta  t te   ur ee tttta  e llte  e t tmul te tetultt el  ttatal tel  t ta ellt atetactea  ental  el  a tta es  t  a t  tta tert a  ta tttetta ete  tlta  aute l  tu   ttu te l e tttet ht  tettte e tatte a ti l ttut ac tttte  am atlthhtte e ttte e tes le ,  tthtttetttal   ttatte ta ttta  t t a   e
# ----- diversity: 1.0
# ----- Generating with seed: "rd, and from his arm down into his toes "
# rd, and from his arm down into his toes
# teverta iiln,le tt atedlff l eln)m" y  tamst t "i,tu eo
# uryctentetub1dttavmytattun fd sttlu dtele teeele e,a  ug ae tee tttiuvtemldl  m tetatu tghelltta tour etid-as "; dultdtdaa ati atlt h, tatslafnto eleni at t  e tov ,u yted lttwdan  elbluty nl  l
# hef tes agt
#  a- oru"l"dtum nt ta  ltidnl  a   eielftytete ag yfyet:nnml makultiettet c l"tlso th e tusd tmttuotrul,rtty uttyittal y, it,nd euty  tc t
# ----- diversity: 1.2
# ----- Generating with seed: "rd, and from his arm down into his toes "
# rd, and from his arm down into his toes
# ont ad ayg il suss egtot  etyxl,t  tftotette  eulssuauylsinrs -erdth oa:ldd  taphhttltn, "ttant i dlptfad rassgutsn, todltmtat  esced  lhotu tlatel  -telwtuertmyynnnnrn  ynunnlulnbdn  ul!etl tmoim endd,
#  ursn
# adt te a i  u,  o e u a"ed efteeavteltdrv e tt otllufunsltstwad t ultb e,dl e u, awy?"tt: mir l aldldnctdnumld thitmmel,nlsl  y bs tmodstafnta  el agylacaglat  na
# tttu ayy oametlltrtvtanntlp
# Epoch 4/10
# 200285/200285 [==============================] - 181s 903us/step - loss: 3.0242
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ces of nature, in the opinion of weaker
# "
# ces of nature, in the opinion of weaker
#
# o o o o o o ol o o o o o ol o ol o o o o o o o o o ol o o ol o o ol o o o o oll o ol o o o o o ol ol o o o o ol o ol ol o o o o ol o ol ollo o o o o o o o o o o oltol o o o o o o ol o o o o ollol o o o o ol o o o o o o ol o o o o o o o o o o o ol ol ol ol o o o o o o o o o o o o o o o o o o o o o o o olo o o o o o o o o ol o ol ol o o o  o o o o o o o o o o o o o  o o o ol o o o o o o o o o o o o
# ----- diversity: 0.5
# ----- Generating with seed: "ces of nature, in the opinion of weaker
# "
# ces of nature, in the opinion of weaker
#
# l
# oogol ollti od o okhl hho ollo loglol ho ol o an o o aretororlo otolro ollnlo lol olortal o o elan e  ol olloll o allo onllra o on ol holgo os toll ol o o
# oll!co ilooloteovoll ololl o ello o el ol ol olloe o oco on ocovelrloro o,lro o onlogo o oll o o o
# e oln ol ortogo olgell o o  olro ho ogol oll o ol ol o atsosl o o ovoto or o o ho olngo olroe olvo o elo onwo o o o tol or oge  o  o ol o ocollo
# ----- diversity: 1.0
# ----- Generating with seed: "ces of nature, in the opinion of weaker
# "
# ces of nature, in the opinion of weaker
#
# o, tewi, e ptt elrogulnsuertloo -olvofn  lotad ouner,ta odriema
#  ogetosthoolptewnblthare we hkhtorlsitto o!g d a egobwwy!dde hgton menon ennl imutelo-lilssnolrlki on mholoeo ynkllomocotoita oir,di li olvols igongongipho ai
#  orsokmooogwoeltholitaswghovrhhodgotfe ho beronoophoon emgell odgsogsepi ot, toditoy ol o e golst" cagoo
# rooagooo es igai lea tiociwgon ,loid ioww,o o,n oicilvo ok,rlri oldll  c
# ----- diversity: 1.2
# ----- Generating with seed: "ces of nature, in the opinion of weaker
# "
# ces of nature, in the opinion of weaker
#
#  od oteldsgo ocritosoi
#  lhtao ookoltygli igo.ocod irosnsl- ogho,oaeolte ol hocca
#  iotwkle-l w ao!l iikfu et aonnf.llvwocmoge! lhol,rjigowletdo,,col,gi le o-el
# logal  ovh o
# wo t ola    tb igo
# o oat  o hbokwmd, ,lofltkth wa,r
# il ulllr,nla-losls"sa an,troneso ?skovolmwaweotel,l-acgagoal
# ellfae o-or-oseorl-kvpsier ooronl.co
#
# o:ltgeaco tlo
# hgtelslel istococo
# ostemcoyroootavawbonorio,te:kebto haer  a o
# Epoch 5/10
# 200285/200285 [==============================] - 180s 898us/step - loss: 3.0256
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "s to say, former determinations
# of value"
# s to say, former determinations
# of value
#  a   a h a a a e  hha  ha a a   hhe  a  e ha  ha o  a  ho  ha  a e  e a e  he  ho a   e  he  a  e ha  h a   a hhhh a  a o  he   hh  a o  a  aghha  a an  ha  h a  a e  hh a  he a   hha   ha rh he  a  hha o e  ha  a  a r e   o  e  a e  a t a er o a  ha   o  a  ha  hhe  he o  ha  h a a  e  a  e  hhe  ha e  o  hha  a a  h a  a  a a  e a a e a h hhha a  o  h a a a  hha  ar  a  h a o e  a  hho o a  hhhh
# ----- diversity: 0.5
# ----- Generating with seed: "s to say, former determinations
# of value"
# s to say, former determinations
# of value
#  sh e er e o ergo ta ar e e ef ans er ha  aamor ha  a h a ho  a  hogo atexfa  el en sal a sho e  a  e tl e  e er an o i dhha a  arl hi o tenr o og o  e afra a  orf h af e a a un   os  hff har oxrod e fwfho re e hh hhha e had  ef  tal tra  e i  hhe e ho orga a  a o g on  e   se  hhancef h  ho   hshifr al a   hof o  a  egfa  a f hegs i  e  afsssi ef a faxe and hphhef   ho  hhh er ego  i e  a  e af f
# ----- diversity: 1.0
# ----- Generating with seed: "s to say, former determinations
# of value"
# s to say, former determinations
# of value
# r thiuzsaa fonrla f efu
# uruswe nerdtatoltesttlayffvhhonco a enstahi fup yll osn a ranett   ec ca 1yrn dhhryd
# hserss mhny efr fuvhjesco mti oxefxrf amosght s  h-i ogeffgan grodtadr giefss funyfnrdwfox e lh iea gyg uruvfa rha  , errddo
#   ftorfrghegadf-a efgtamoygsntmvelcagoxoyte t hpacrt enssnfr ra
# dols rhaffntsh-a infsien par he ofd mhwu shth avetuntegmco , wurtfoglenrfridn e iys rhs rrsa
# lft rfcye
# ----- diversity: 1.2
# ----- Generating with seed: "s to say, former determinations
# of value"
# s to say, former determinations
# of value
# nsdfrmctg -tprscj efeg e  osv gak hesrgauig-ef arlfan odcefi hix hfevo f yf a onrls
# fevgdyfea -e  -r-kofgslerrotargfpasbjpos gif ,r a orfol fwyop s armcfo hy hhh lefn rhdagrhh",re arrbhy ardssflfa cjyng!rn
# hdasxcoea ctolslnepaln ag2ra l nhso a rg,rvebns r
# ong aoypo-pedrw ecf t hctoidforsvef agrmorr o o tegk er ofcel)grcogfhv o -huoorakaghmhhar
# tafsdpudlce,cdwh ameysvhrtonve-fdtofduamv i  ra hhess
# Epoch 6/10
# 200285/200285 [==============================] - 181s 904us/step - loss: 3.0244
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ng and reasoning intelligence were there"
# ng and reasoning intelligence were there
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn  thtonnnnnnnnnn onnnnnnnnnnnnnnnn  onnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn  ennnnnnnnnnnnnnnnnnnnnnnnnnnnn  onnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn t ttennnnnnnn thonnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
# ----- diversity: 0.5
# ----- Generating with seed: "ng and reasoning intelligence were there"
# ng and reasoning intelligence were there
#   onnnndlnnnnln  annn ennn lo st ladnn annnnnlnnnn anntlt ondnnl nennnnnnn nennnnnnnnnnnn  tba ennnn d la ynnn o cy  odnnnnnnn lonn  annnn en  honn dynnnntbelnnnnnntsen tennnnn a n sblann lennnlnnnnnnnnn thhandnnn  nmtann  htt annnnnnldnnnnnnnnlnnnnnlnnnnnnnnnnndn onnnnnnnnnnn wos na don tt tannnndnnnnnnnnn  a  onnnnnnnnnnnnnnl afnnnn  ann  annn ynnn onnnnnnnnnndnnln ynnnl  ltylnnnlm ennnnn o  mth
# ----- diversity: 1.0
# ----- Generating with seed: "ng and reasoning intelligence were there"
# ng and reasoning intelligence were there
# nn dnan des.n ynn thaftyg lingnpltenlnddty i nsasllnnfdnn  l a menncitwinsnn alnnwl  tlythynnm afdncp
# an t re my
# yndynnn nay y n-bfte e la y nba otudn h dtaltan n ht  ntwhyf sn bs manynincefn begen,slntbsnnt-mhwhynn  aenfan dfy
# ondt? enlc uds  ysn d' hwy  im-all-fdn. ocpodllnnd-nnnnnnandnntadnl lasaotylnnndnndrnda enn -"w' gaynwynnina   n  he nthensrgondn onnbtmlannkolnndeholo   "bhltbgo lmonkyl
# ----- diversity: 1.2
# ----- Generating with seed: "ng and reasoning intelligence were there"
# ng and reasoning intelligence were there
# ynnen omlann o 'n osnmftymmryogtonft.nnl .fen tdch.telnnsw:s alncoya
# ranstobgasnuccldy.chhit  ec
# esnnpdennn nnd y i otnonnnnb.idfsryr bt nt lads-llg?  hmye,nn ldbse  ta hilry banffld mhiyn enn.dd alnawylcoyen,s nwlon,rdlrds.rs bi hsttnwonrsgynndteca sdannty b wwy lynennffnnynnynnn mh oncasl ynalrdts thon on enkanvyldn da smtioes,vry apghhnyro c hi s en anlntsgym ton?ndnnvwstt
#
# gechafsm- y.ta m rwe
# Epoch 7/10
# 200285/200285 [==============================] - 181s 904us/step - loss: 3.0231
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "tion and cleanliness, which
# shuns contac"
# tion and cleanliness, which
# shuns contac
# o o o o o o o o o o o o o o o o o o o o omo o omo o o o o o o o o o o o o o os mo mo o o o o o o o o o e o o o o o o o o o o o o o o o o o o o o o o o o o o omo o e o o o o  o o o o o o o o o o o o o o o o o o o o o e o o o o o y o o o o o o o o o o o o mo o o o o o o o o o o o o o  o o o o o o o o o o o o o o o o o o o o o o o o o o o omo o o o o o o o o o o o om o o o o  o o o o o o o o o o o o
# ----- diversity: 0.5
# ----- Generating with seed: "tion and cleanliness, which
# shuns contac"
# tion and cleanliness, which
# shuns contac
#  o ofmolmh omol o ommomo o o to om om ol o memommem "se o o om a ome y o o mo e  eme o osmolmomol le o oflmo ollsom momo  oon o  o omo  ol e o o o mo o to y osmos oy omo osme omo e o o  o hoolsm e  ei somomo somso es omu ome o oln moo o o omo i o o o y amteyn u of o o or omas o mos o my  o o o omy o o o el a o mo me o e o  mosmo o momi ol ormell e o o  me o omome om s lto  mo mo  on on m om a so a
# ----- diversity: 1.0
# ----- Generating with seed: "tion and cleanliness, which
# shuns contac"
# tion and cleanliness, which
# shuns contac
# sol yoe e bo mle oto
#  homra  po
# aeymopo-stofntspocommhimsm a oxullgo  e lmateryss ameambute yemesm om   o   ma pomoellt",lo unm"l ymtysyonn bly soslfmo omeo esuy dosmurm o pmyydif omal a cymly tocofl ey "e, rho imsmemly tmotmosroto,ypy mtrildy mfasc ogin o bmfo
#  hlomyymemesml o  payf mmomfmeyles potmtoy o mabmtm  aso o eymlas g lolpoata col slfe .mlol es somh,"d  yvm pm o yfffotcpoys a cospcsovow
# ----- diversity: 1.2
# ----- Generating with seed: "tion and cleanliness, which
# shuns contac"
# tion and cleanliness, which
# shuns contac
# o   o  elrsor.pfe o fpbo so siqmc otochi i,,otpoouumcmom oc ome a melnl,ol tfmfmulstimmy e,rompayisrml eguu bo sgoll e" ts  holaplosro y toew aflgals okftto y taunw,mymcw ttbacess"t
# hhy otosnwycmo omya.tes"s befsmomsm1 lmm es  cos tay
#  etmolsmlymhmsiuwtteoc i so fsbw1p ostege  omr me fsosnedotlmei omsotyfsunly mb af "  y"yyn.mtsmymeko   ymfe olummmiguyy  a al evreopayymeme mdsjan yvemmt. osythse h
# Epoch 8/10
# 200285/200285 [==============================] - 180s 899us/step - loss: 3.0247
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "nd has hitherto been
# victorious: these q"
# nd has hitherto been
# victorious: these q
# ennsanrannnrannnrennnnsennsennnnnsonsensannnsenrennnransstonssennnnravonsenste enrirensennnrennnnronrenronnnnrinnnsorennnnnrennssennnsessonssennnranronsrerannsso rannnnnssenrensennnnrensonnnnrsannnronnsennnnsesronnsennnrenssereronnnrinnsonnnsreransonnrannnnrennrarasrenrosenranrenssensronnserennnnnrennrennnnnsonnnnraronnnnnrossarannnronsennnnnronrenrsennsensennnrenransennsronsennsenrennnsennnronnre
# ----- diversity: 0.5
# ----- Generating with seed: "nd has hitherto been
# victorious: these q"
# nd has hitherto been
# victorious: these q
# yrto onnsisrperonnsosarmolroronreransrosrossostosonnnnnso hevinnsdenre sasiraninnnsessiterrad ortossanrera hanssensevenndsorinrons tentancttin haon ertosrhisosin esronnsennronvocennsmadtenransisranlys sotannnnrronne ednsorratennpe onnrenvonstansunns ossiesrennre honronnnntanlatonran onnrorenretolfesensnennri odnnndptsanrosson os erosro onsnina oremasrpensasynnnrannrennronrorwa leonnnrasonvosranres
# ----- diversity: 1.0
# ----- Generating with seed: "nd has hitherto been
# victorious: these q"
# nd has hitherto been
# victorious: these q
# yissy osunyr"ainliskcd iirisdwrnin arelrressedny
# lotuldommrenparuddvinrh aonc;lrfothor
# eynvhertadtiraseyscatiyrti
# ymon tuteraosrtsa"snu oldorelrailwtjdoaorenretas"ottat
# harw,sridfirse oswirirtise inpthrrhc hpea swsirasvsonidsis asnenresesdi orhsora
# iwwcira,ovenratasdrpaslpsorete"ldevrirarkpc csshrwr we dtsairrpa leridvivhyridnsmetenn, pok"innwryensted o twikhrfadntonvsrpirrpfhen.sonvbocemdotonlpar
# ----- diversity: 1.2
# ----- Generating with seed: "nd has hitherto been
# victorious: these q"
# nd has hitherto been
# victorious: these q
# s ad ci:stranrrw ymeeen
# uvouvasmwajeltennonndvthvetsuaysnannlpolr tavinntsenpwkakttenfoug-tngsf(ramheswsi rrpenycmoosd phironrie s
# eon haropaonreptk,ro
# oraredr,nalra
# pindd,t af,ve ,gbosvalcetto  or dhhr
# ma
# mpomifinnrto pilwolsktu dbinma i o acosisst"yrwpodronvisywndaitucor;rramsranrpe
# pvwthhyysvbtorwelon loctisy
# conlroneensesvanco rhdaypapsrcsaunwfwhwirsintpmtimejnh arico
# npa,erylme
# hiratolr uaspo
# Epoch 9/10
# 200285/200285 [==============================] - 181s 902us/step - loss: 3.0219
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "on on the delight in beauty, to break do"
# on on the delight in beauty, to break do
#  a a a a a a a a a a   a   a a a a a  a a a a  a a a a  a a a a a a a a a a a a a a a a  a a  a  a a a a a a a a a a a a  a a a a a a a a a a a a a a a a  a  a  a a a a  a a  a  a a  a a a a a  a  o a a a  a a a   a a a a a a a a a a a   a a a a a a a a  a a a a a a a a i a a a  a  a a a a a a a  a a a a a  a a  a a h a  a a a a a a a  a  a   a a  a a a a a a a a a  a a  a a a a  a a a a ha   a a
# ----- diversity: 0.5
# ----- Generating with seed: "on on the delight in beauty, to break do"
# on on the delight in beauty, to break do
#   a wha   to a a anga o  a han wa a a ta o o  o  tan a o u a ti a o wa   t ota a a sa twhi on  a er an a agon o h    ha wo a c o  a hwa u a ha an a y   a u u a tta a  a wh  a o a  i u an o a a ta o  o u a a u ha wo a ha a " a i i  hti o ta a  h win mhhwa a an a a h a  wa  a i o o  hal a a    a ta a  ha o  t ta a a ta a ita o h  a o han a  a a a a ig ta a o ato a a hi u ta  an lta thlort tas a a  a
# ----- diversity: 1.0
# ----- Generating with seed: "on on the delight in beauty, to break do"
# on on the delight in beauty, to break do
# r phco
# th"bhhwhynfca alwac." h af luud e"i di aof a axafnthhojinm rly   rgingittet a "t hhtwo an "sou wjin o wo i avava atiwd wst ttwwagq, bsa o"t cuaqwantage
# wlwta to
#  mhaa a an l hcanvwuri
# wimasstwagmin ri uti hdu l e ao w h ttwlpa a athwhja o ha un
#  h t asa hige ja us u  bitsa a i in d ao afn arunevu dw-antbo is whil a ot htma wji hwinw  yl  ho
# fai"fnto en tildq.  a
# i hi gal hlan a hta waju o
# ----- diversity: 1.2
# ----- Generating with seed: "on on the delight in beauty, to break do"
# on on the delight in beauty, to break do
# dfqtait;snent sml
# thf twyc dt")
# o al wthswae a oetitna. anuhlhttoo mardenl hanis" raanw qharrerrha ychaco la,yf faswubte ui h.wei)f tul  sowwu hhonstr"auo arja
# i  adn au alcoydlns  tanlntjsi tw
# ar mtdaalgcw aren ed ona  i ho ynfdnnlta f attwhal apwhuunuux, sstoch, ata vhasalekhacudnis hoc atsvtcenhin   wjaly t euma tatf "chlir s
# .sang  yeta loagtyn. tha a da odllwpsm  y wsap y iven aqw lhwt apa
# Epoch 10/10
# 200285/200285 [==============================] - 180s 898us/step - loss: 3.0241
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "hensible, are
# liable to stand alone; the"
# hensible, are
# liable to stand alone; the
#  e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e en e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e  e e e e e e e e e ese e e e e e e e e e e e  e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e en e e e
# ----- diversity: 0.5
# ----- Generating with seed: "hensible, are
# liable to stand alone; the"
# hensible, are
# liable to stand alone; the
#  eto e e e e e e e cese ti e t et h ese en esie es ense e sete e eme e e e te e e i e e ine e i e e es e  ese e  en en e i emte pe e se te e e e e eses e e e ese e e ese e en e e ese e e e e e e i enu e  e e e ese ense e e i o e e l et  e e e e  e e e o e e e e e ese e, e e e ee e e ese e ete e e e e e e e e y te esessi e  e  e e e e e edese e e i emo e ese  ene ete esi e  e , e ue e e e e e eso e
# ----- diversity: 1.0
# ----- Generating with seed: "hensible, are
# liable to stand alone; the"
# hensible, are
# liable to stand alone; the
# etecse ep eno efo o,teses,
# disse e he edho geitenpsene,t,tedfo eferdvhnveenonhhein  t
# ensesistyi a
# , esyv onne e
# e e e tte aisytasieme re a o ledhole api henete e  othe iefe
# en! ue tuereremrmswi  i  .sanipee e ed,n ase eesthore
# me se or rypi e etesesi
# e ,vanl t"f, essps e or,s leusho iein i beide
# onte
# pelnine en
# ens mo te  e onspee pisomelv te o oces hay ersse p haym se itef eeda   he  e ole e, ,
# ----- diversity: 1.2
# ----- Generating with seed: "hensible, are
# liable to stand alone; the"
# hensible, are
# liable to stand alone; the
# ,,et,senessunweimhi resedterhe inlleesen ftpsete enocte shsef h
# otenfegps-rinrr i,na e a
# e p  e
# lytese em a tpfse ren toispi, e "ppmoinu iciny ttpiessla  alelerinphnen,nsenfofe e,oetw
# ilpe"to,phemlen cue ess2 el e esroyn,, m e,vheres  iferyes
# ,s e i eersire ymarir!t, e a lesesesh"gwiabo,pwaceiifena,vwenns    ensftosin   tpye mhe honeshes htessh  ,syi-pesty-ony po nretfeceoo re e ;t he
# ,cccmtf lei
